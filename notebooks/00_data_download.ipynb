# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/data.csv')

# %%
# Cria o dicionário de dados

data_dictionary = pd.DataFrame([
    {
        'variavel': 'gender',
        'descricao': 'Gênero do individuo',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    },
    {
        'variavel': 'age',
        'descricao': 'Idade do individuo',
        'tipo': 'quantitativa',
        'subtipo': 'continua',
    },
    {
        'variavel': 'hypertension',
        'descricao': 'Individuo apresenta hipertensão',
        'tipo': 'quantitativa',
        'subtipo': 'discreta',
    },
    {
        'variavel': 'heart_disease',
        'descricao': 'Individuo apresenta doença cardiaca',
        'tipo': 'quantitativa',
        'subtipo': 'discreta',
    },
    {
        'variavel': 'smoking_history',
        'descricao': 'Historico de tabagismo',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    },
    {
        'variavel': 'bmi',
        'descricao': 'IMC do individuo',
        'tipo': 'quantitativa',
        'subtipo': 'continua',
    },
    {
        'variavel': 'HbA1c_level',
        'descricao': 'Nivel da hemoglobina A1c',
        'tipo': 'quantitativa',
        'subtipo': 'continua',
    },
    {
        'variavel': 'blood_glucose_level',
        'descricao': 'Nivel de glicose no sangue',
        'tipo': 'quantitativa',
        'subtipo': 'continua',
    },
    {
        'variavel': 'diabetes',
        'descricao': 'Individuo apresenta diabetes',
        'tipo': 'quantitativa',
        'subtipo': 'discreta',
    }
])

# Salva o dicionário de dados
data_dictionary.to_csv("../data/external/dictionary.csv", index=False)

# %%
data_dictionary
# Out:
#               variavel                            descricao          tipo  \
# 0               gender                  Gênero do individuo   qualitativa
# 1                  age                   Idade do individuo  quantitativa
# 2         hypertension      Individuo apresenta hipertensão  quantitativa
# 3        heart_disease  Individuo apresenta doença cardiaca  quantitativa
# 4      smoking_history               Historico de tabagismo   qualitativa
# 5                  bmi                     IMC do individuo  quantitativa
# 6          HbA1c_level             Nivel da hemoglobina A1c  quantitativa
# 7  blood_glucose_level           Nivel de glicose no sangue  quantitativa
# 8             diabetes         Individuo apresenta diabetes  quantitativa
#
#     subtipo
# 0   nominal
# 1  continua
# 2  discreta
# 3  discreta
# 4   nominal
# 5  continua
# 6  continua
# 7  continua
# 8  discreta
